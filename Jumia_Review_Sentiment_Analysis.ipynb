# %% [markdown]
# <a href="https://colab.research.google.com/github/JairusTheAnalyst/JairusTheAnalyst/blob/main/Jumia_Review_Sentiment_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import nltk
from nltk.sentiment import SentimentIntensityAnalyzer

nltk.download('vader_lexicon')

# Sample Jumia review dataset (expanded)
data = {
    "review": [
        "The delivery was fast and the product quality is excellent.",
        "Terrible experience! My order arrived broken and late.",
        "Average product, not too bad but not great either.",
        "I love shopping on Jumia, always reliable.",
        "Customer service was unhelpful and very slow.",
        "Received wrong item but support resolved it quickly.",
        "Pricing is good but delivery is inconsistent.",
        "Excellent discounts during the sale period!",
        "Product packaging was damaged, disappointed.",
        "Very happy with the mobile phone I bought.",
        "The website is slow, and checkout was confusing.",
        "Fast delivery, good quality, will buy again.",
        "Support team was rude, won't recommend.",
        "Easy to use app and smooth payment options."
    ]
}

# Create DataFrame
reviews = pd.DataFrame(data)

# Initialize VADER sentiment analyzer
sia = SentimentIntensityAnalyzer()

# Apply sentiment analysis
def analyze_sentiment(text):
    score = sia.polarity_scores(text)['compound']
    if score > 0.1:
        return "Positive"
    elif score < -0.1:
        return "Negative"
    else:
        return "Neutral"

reviews["sentiment"] = reviews["review"].apply(analyze_sentiment)

# Display results
print(reviews)
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
#                                                review sentiment
# 0   The delivery was fast and the product quality ...  Positive
# 1   Terrible experience! My order arrived broken a...  Negative
# 2   Average product, not too bad but not great eit...  Negative
# 3          I love shopping on Jumia, always reliable.  Positive
# 4       Customer service was unhelpful and very slow.   Neutral
# 5   Received wrong item but support resolved it qu...  Positive
# 6       Pricing is good but delivery is inconsistent.  Positive
# 7         Excellent discounts during the sale period!  Positive
# 8        Product packaging was damaged, disappointed.  Negative
# 9          Very happy with the mobile phone I bought.  Positive
# 10   The website is slow, and checkout was confusing.  Negative
# 11       Fast delivery, good quality, will buy again.  Positive
# 12            Support team was rude, won't recommend.  Negative
# ...
